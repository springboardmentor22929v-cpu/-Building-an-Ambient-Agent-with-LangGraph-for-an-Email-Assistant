# %%
# %pip install langgraph langchain langchain-google-genai langsmith python-dotenv
# Out:
# Requirement already satisfied: langgraph in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (1.0.5)
# Requirement already satisfied: langchain in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (1.2.0)
# Requirement already satisfied: langchain-google-genai in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (4.1.2)
# Requirement already satisfied: langsmith in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (0.6.0)
# Requirement already satisfied: python-dotenv in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (1.2.1)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langgraph) (1.2.6)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langgraph) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langgraph) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langgraph) (0.3.1)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langgraph) (2.12.5)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (0.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langsmith) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langsmith) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langsmith) (0.25.0)
# Requirement already satisfied: anyio in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.12.0)
# Requirement already satisfied: certifi in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from langchain-google-genai) (1.56.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.45.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.45.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from requests>=2.0.0->langsmith) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from requests>=2.0.0->langsmith) (2.6.2)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\sai usha\documents\ambient_agent_langgraph\-building-an-ambient-agent-with-langgraph-for-an-email-assistant\.venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langgraph.graph import StateGraph, END
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage
from pydantic import BaseModel
from typing import Literal, List
import os

# %%
#Load environment variables
from dotenv import load_dotenv
import os

load_dotenv()

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
USER_EMAIL = os.getenv("USER_EMAIL")

print("Google API Key loaded:", GOOGLE_API_KEY is not None)
print("User Email:", USER_EMAIL)
# Out:
# Google API Key loaded: True
# User Email: skpriya.gande@gmail.com

# %%
#Define Email State
from pydantic import BaseModel, Field
from typing import List, Optional

class EmailState(BaseModel):
    email: str
    decision: Optional[str] = None
    reasoning: Optional[str] = None
    actions: List[str] = Field(default_factory=list)

# %%
#Safe Mock Tool
def read_calendar():
    return "Calendar is free tomorrow at 10 AM"

# %%
#Local/Fallback LLM
try:
    from langchain_google_genai import ChatGoogleGenerativeAI

    llm = ChatGoogleGenerativeAI(
        model="models/gemini-1.5-pro",
        temperature=0,
        google_api_key=GOOGLE_API_KEY
    )
    # simple test
    llm.invoke("Say OK")
    print("Gemini connected successfully")
except Exception as e:
    print("Gemini unavailable, using LocalLLM fallback")

    # ✅ Error-free LocalLLM
    class LocalLLM:
        def invoke(self, prompt: str):
            p = prompt.lower()
            if "meeting" in p or "schedule" in p or "tomorrow" in p:
                result_content = "respond"
            elif "win" in p or "free" in p or "offer" in p:
                result_content = "ignore"
            else:
                result_content = "notify_human"

            # Correctly return object with content
            class Result:
                def __init__(self, content):
                    self.content = content

            return Result(result_content)

    llm = LocalLLM()
# Out:
# Gemini unavailable, using LocalLLM fallback

# %%
#Triage Node
def triage_node(state: EmailState):
    prompt = f"""
Classify the email into one of these:
ignore
notify_human
respond

Email:
{state.email}
"""
    result = llm.invoke(prompt)
    state.decision = result.content
    state.reasoning = f"Classification done for user {USER_EMAIL}"
    return state

# %%
#ReAct Node
def react_node(state: EmailState):
    if state.decision == "respond":
        state.actions.append(read_calendar())
    return state

# %%
#Build LangGraph
from langgraph.graph import StateGraph, END

graph = StateGraph(EmailState)
graph.add_node("triage", triage_node)
graph.add_node("react", react_node)

graph.set_entry_point("triage")
graph.add_edge("triage", "react")
graph.add_edge("react", END)

agent = graph.compile()
print("LangGraph agent compiled successfully")
# Out:
# LangGraph agent compiled successfully

# %%
#Test Single Email
result = agent.invoke(
    {"email": "Can we schedule a meeting tomorrow at 10 AM?"}
)

# Handle both dict and BaseModel safely
if isinstance(result, dict):
    decision = result.get("decision")
    reasoning = result.get("reasoning")
    actions = result.get("actions")
else:
    decision = result.decision
    reasoning = result.reasoning
    actions = result.actions

print("Decision:", decision)
print("Reasoning:", reasoning)
print("Actions:", actions)
# Out:
# Decision: respond
# Reasoning: Classification done for user skpriya.gande@gmail.com
# Actions: ['Calendar is free tomorrow at 10 AM']

# %%
#Golden Dataset (Evaluation)
golden_set = [
    ("Win a free iPhone now!!!", "ignore"),
    ("Please review the attached report", "notify_human"),
    ("Can we meet tomorrow morning?", "respond"),
    ("Limited offer just for you", "ignore"),
    ("Need approval for budget", "notify_human"),
    ("Schedule a call at 10 AM", "respond"),
] * 5  # 30 samples

# %%
#Accuracy
correct = 0
for email_text, expected in golden_set:
    result = agent.invoke(EmailState(email=email_text))
    if isinstance(result, dict):
        predicted = result.get("decision")
    else:
        predicted = result.decision

    if predicted == expected:
        correct += 1

accuracy = correct / len(golden_set)
print(f"Triage Accuracy: {accuracy*100:.2f}%")
# Out:
# Triage Accuracy: 100.00%
